# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import csv

# %%
url= "https://ghoapi.azureedge.net/api/SA_0000001476"

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
response = requests.get(url).json()

# %%
type(response)
# Out:
# dict

# %%
df1 = pd.DataFrame(response)
display(df1)
# Out:
#                                         @odata.context  \
# 0    https://ghoapi.azureedge.net/api/$metadata#SA_...
# 1    https://ghoapi.azureedge.net/api/$metadata#SA_...
# 2    https://ghoapi.azureedge.net/api/$metadata#SA_...
# 3    https://ghoapi.azureedge.net/api/$metadata#SA_...
# 4    https://ghoapi.azureedge.net/api/$metadata#SA_...
# ..                                                 ...
# 500  https://ghoapi.azureedge.net/api/$metadata#SA_...
# 501  https://ghoapi.azureedge.net/api/$metadata#SA_...
# 502  https://ghoapi.azureedge.net/api/$metadata#SA_...
# 503  https://ghoapi.azureedge.net/api/$metadata#SA_...
# 504  https://ghoapi.azureedge.net/api/$metadata#SA_...
#
#                                                  value
# 0    {'Id': 4529097, 'IndicatorCode': 'SA_000000147...
# 1    {'Id': 4519726, 'IndicatorCode': 'SA_000000147...
# 2    {'Id': 4539508, 'IndicatorCode': 'SA_000000147...
# 3    {'Id': 4519696, 'IndicatorCode': 'SA_000000147...
# ...

# %%
outer_dict = response

inner_dicts = list(outer_dict.values())

innerdict2 = inner_dicts[1]

df3 = pd.DataFrame(innerdict2)

display(df3)
# Out:
#           Id  IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0    4529097  SA_0000001476        COUNTRY        ROU        YEAR
# 1    4519726  SA_0000001476        COUNTRY        CAN        YEAR
# 2    4539508  SA_0000001476        COUNTRY        GEO        YEAR
# 3    4519696  SA_0000001476        COUNTRY        ZWE        YEAR
# 4    4529109  SA_0000001476        COUNTRY        ARM        YEAR
# ..       ...            ...            ...        ...         ...
# 500  4529070  SA_0000001476        COUNTRY        NOR        YEAR
# 501  4519711  SA_0000001476        COUNTRY        KGZ        YEAR
# 502  4539579  SA_0000001476        COUNTRY        RUS        YEAR
# 503  4529193  SA_0000001476        COUNTRY        FIN        YEAR
# 504  4539575  SA_0000001476        COUNTRY        ARM        YEAR
#
#     ParentLocationCode ParentLocation Dim1Type  Dim1  TimeDim  ...  \
# 0                  EUR         Europe     None  None     1997  ...
# ...

# %%
df3.to_csv('./who_per_income.csv', index=False)
